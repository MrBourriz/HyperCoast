# %%
import hypercoast
# Out:
# <xarray.Dataset> Size: 71MB
# Dimensions:      (wavelength: 235, x: 332, y: 229)
# Coordinates:
#   * wavelength   (wavelength) float64 2kB 401.4 404.1 406.7 ... 997.8 1e+03
#   * x            (x) float64 3kB 6.601e+05 6.602e+05 ... 6.7e+05 6.701e+05
#   * y            (y) float64 2kB 3.259e+06 3.259e+06 ... 3.252e+06 3.252e+06
#     spatial_ref  int32 4B ...
# Data variables:
#     reflectance  (y, x, wavelength) float32 71MB ...
# Attributes:
#     crs:      EPSG:32615

# %%
file_path_enmap=r'D:\PhD_Thesis\testoo\EnMAP.tif'

# %%
dataset = hypercoast.read_EnMAP(file_path_enmap,metadata_url=r'D:\PhD_Thesis\testoo\enmap_wavelengths_full.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dataset = hypercoast.read_EnMAP(file_path_enmap,metadata_url=r'D:\PhD_Thesis\testoo\enmap_wavelengths_full.csv')
#
# AttributeError: module 'hypercoast' has no attribute 'read_EnMAP'

# %%
dataset
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:      (y: 1185, x: 1278, wavelength: 224)
# Coordinates:
#   * wavelength   (wavelength) float64 2kB 418.4 424.0 ... 2.438e+03 2.445e+03
#   * x            (x) float64 10kB 2.29e+05 2.29e+05 ... 2.673e+05 2.673e+05
#   * y            (y) float64 9kB 3.76e+06 3.76e+06 ... 3.725e+06 3.725e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     reflectance  (y, x, wavelength) float32 1GB nan nan nan nan ... nan nan nan
# Attributes:
#     crs:      EPSG:32630

# %%
hypercoast.filter_desis(dataset, lat=31.5315, lon=5.4550)
# Out:
# <xarray.DataArray 'reflectance' (wavelength: 224)> Size: 896B
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...
