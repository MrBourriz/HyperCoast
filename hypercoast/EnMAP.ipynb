# %%
import hypercoast

# %%
file_path_enmap=r'D:\PhD_Thesis\testoo\EnMAP.tif'

# %%
dataset = hypercoast.read_EnMAP(file_path_enmap)

# %%
dataset
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:      (wavelength: 224, x: 1278, y: 1185)
# Coordinates:
#   * wavelength   (wavelength) float64 2kB 418.4 424.0 ... 2.438e+03 2.445e+03
#   * x            (x) float64 10kB 2.29e+05 2.29e+05 ... 2.673e+05 2.673e+05
#   * y            (y) float64 9kB 3.76e+06 3.76e+06 ... 3.725e+06 3.725e+06
#     spatial_ref  int32 4B ...
# Data variables:
#     reflectance  (y, x, wavelength) float32 1GB ...
# Attributes:
#     crs:      EPSG:32630

# %%
m = hypercoast.Map()
m.add_basemap("Hybrid")
m.add_EnMAP(file_path_enmap,wavelength=[660,571,477], vmin=0, vmax=5000, nodata=-32768)
m.add_colormap(cmap="jet", vmin=0, vmax=0.5, label="Reflectance")
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
m = hypercoast.Map()
m.add_basemap("Hybrid")
m.add_EnMAP(file_path_enmap, wavelengths=[900, 600, 525], vmin=0, vmax=1000)
m.add("spectral")
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# File d:\PhD_Thesis\testoo\hypercoast\ui.py:237, in SpectralWidget.__init__.<locals>.handle_interaction(**kwargs)
#     234 elif self._host_map.cog_layer_dict[layer_name]["hyper"] == "AVIRIS":
#     235     da = extract_aviris(ds, lat, lon)
# --> 237 self._host_map._spectral_data[f"({lat:.4f} {lon:.4f})"] = da.values
#     239 if self._host_map.cog_layer_dict[layer_name]["hyper"] != "XARRAY":
#     240     da[da < 0] = np.nan
#
# UnboundLocalError: cannot access local variable 'da' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# File d:\PhD_Thesis\testoo\hypercoast\ui.py:237, in SpectralWidget.__init__.<locals>.handle_interaction(**kwargs)
#     234 elif self._host_map.cog_layer_dict[layer_name]["hyper"] == "AVIRIS":
#     235     da = extract_aviris(ds, lat, lon)
# --> 237 self._host_map._spectral_data[f"({lat:.4f} {lon:.4f})"] = da.values
#     239 if self._host_map.cog_layer_dict[layer_name]["hyper"] != "XARRAY":
#     240     da[da < 0] = np.nan
#
# UnboundLocalError: cannot access local variable 'da' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# File d:\PhD_Thesis\testoo\hypercoast\ui.py:237, in SpectralWidget.__init__.<locals>.handle_interaction(**kwargs)
#     234 elif self._host_map.cog_layer_dict[layer_name]["hyper"] == "AVIRIS":
#     235     da = extract_aviris(ds, lat, lon)
# --> 237 self._host_map._spectral_data[f"({lat:.4f} {lon:.4f})"] = da.values
#     239 if self._host_map.cog_layer_dict[layer_name]["hyper"] != "XARRAY":
#     240     da[da < 0] = np.nan
#
# UnboundLocalError: cannot access local variable 'da' where it is not associated with a value
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# File d:\PhD_Thesis\testoo\hypercoast\ui.py:237, in SpectralWidget.__init__.<locals>.handle_interaction(**kwargs)
#     234 elif self._host_map.cog_layer_dict[layer_name]["hyper"] == "AVIRIS":
#     235     da = extract_aviris(ds, lat, lon)
# --> 237 self._host_map._spectral_data[f"({lat:.4f} {lon:.4f})"] = da.values
#     239 if self._host_map.cog_layer_dict[layer_name]["hyper"] != "XARRAY":
#     240     da[da < 0] = np.nan
#
# UnboundLocalError: cannot access local variable 'da' where it is not associated with a value
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\mbour\anaconda3\envs\PhD\Lib\site-packages\leafmap\map_widgets.py:476, in LayerEditor._on_apply_click(self, _)
#     474 self._layer_spinner.icon = "spinner spin lg"
#     475 self._layer_spinner.unobserve(loading_change, "loading")
# --> 476 self._embedded_widget.on_apply_click()
#     477 self._host_map.cog_layer_dict[self._layer_dict["layer_name"]][
#     478     "tile_layer"
#     479 ].observe(loading_change, "loading")
#
# File c:\Users\mbour\anaconda3\envs\PhD\Lib\site-packages\leafmap\map_widgets.py:872, in RasterLayerEditor.on_apply_click(self)
#     870 # Add support for hyperspectral data via HyperCoast
#     871 if self._xds is not None:
# --> 872     self._host_map.add_hyper(
#     873         self._xds,
#     874         type=self._layer_dict["hyper"],
#     875         wvl_indexes=[index - 1 for index in vis["indexes"]],
#     876         colormap=vis["colormap"],
#     877         vmin=vis["vmin"],
#     878         vmax=vis["vmax"],
#     879         opacity=vis["opacity"],
#     880         nodata=self._nodata,
#     881         layer_name=self._layer_name,
#     882         zoom_to_layer=False,
#     883         layer_index=layer_index,
#     884     )
#     885 elif self._layer_dict["type"] == "COG":
#     886     self._host_map.add_cog_layer(
#     887         self._layer_dict["url"],
#     888         bidx=vis["indexes"],
#    (...)
#     894         layer_index=layer_index,
#     895     )
#
# TypeError: Map.add_hyper() missing 1 required positional argument: 'dtype'
